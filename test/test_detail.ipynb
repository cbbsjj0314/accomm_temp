# %%
# location_table
    # accommodations_id
    # Location_major
    # Location_middle
    # Location_sub

# motel_facilities_table
    # accommodations_id
    # accommodations_main_category
    # 부대시설들 여러 갠데 boolean 타입으로 한다~
    # e.g. exist_WIFI = False

# %%
# accommodations_id, accommodations_main_category는 모두 accommodations_table.csv에서 가져올 수 있음

import pandas as pd
import os
import re
import time
import json
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pyarrow

from config import motel_facilities_dict

# %%
# 셀레니움 웹드라이버 설정
def setup_driver():
    options = Options()
    options.add_argument('--headless')
    return webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)


# URL 생성
def generate_url(base_url, accomm_id):
    return f"{base_url}{accomm_id}"


# URL의 HTML 소스 가져오기
def fetch_page_source(driver, url):
    driver.get(url)
    time.sleep(3)
    return driver.page_source

# %%
def parse_detail_page_data(html, accomm_id, index_num, accomm_main_categories):
    location_table = {}
    motel_facilities_table = {}
    motel_facilities_table[accomm_id] = {'accomm_main_category': accomm_main_categories[index_num]}

    soup = BeautifulSoup(html, 'html.parser')
    script_tag = soup.find('script', type='application/ld+json')
    if not script_tag:
        print(f"No script tag found for accommodation ID: {accomm_id}")
        return {}, {}

    json_string = script_tag.string

    # if not json_string.endswith('}'):
    #     json_string += '"'
    #     json_string += '}'
    # if json_string.count('{') > json_string.count('}'):
    #     json_string += '}' * (json_string.count('{') - json_string.count('}'))

    try:
        json_data = json.loads(json_string)
    except json.JSONDecodeError as e:
        print(f"JSON decoding error for accommodation ID {accomm_id}: {e}")
        print("except Script Tag Content:", json_string)
        return {}, {}

    # 주소 정보 얻기
    address_info = json_data.get('mainEntity', {}).get('address', {})
    address = address_info.get('streetAddress', '')
    parts = address.split()
    
    location_table[accomm_id] = {
        "location_major": parts[0],
        "location_middle": parts[1],
        "location_sub": ' '.join(parts[2:])
    }

    # 부대시설 정보 얻기
    facility_info = json_data.get('mainEntity', {}).get('amenityFeature', [])
    facilities_list = [item['name'] for item in facility_info]

    facilities_status = motel_facilities_dict.copy()
    # 부대시설 상태 업데이트
    for facility in facilities_list:
        if facility in facilities_status:
            facilities_status[facility] = True

    for amenity, is_available in facilities_status.items():
        motel_facilities_table[accomm_id][amenity] = is_available

    return location_table, motel_facilities_table


def crawl_detail_page(base_url, accomm_ids, accomm_main_categories):
    driver = setup_driver()
    location_table = {}
    motel_facilities_table = {}
    
    try:
        for accomm_id in accomm_ids:
            index_num = accomm_ids.index(accomm_id)
            # if index_num == 30:
            #     break

            url = generate_url(base_url, accomm_id)
            html = fetch_page_source(driver, url)
            locations, motel_facilities = parse_detail_page_data(html, accomm_id, index_num, accomm_main_categories)
            
            if not locations or not motel_facilities:
                if not locations:
                    print('No data for locations exist')
                    # print("Cuz no return value from 'parse_main_page_info()'")
                    # print('Current URL:', url)
                if not motel_facilities:
                    print('No data for motel_facilities_table exist')
                    # print("Cuz no return value from 'parse_main_page_info()'")
                    # print('Current URL:', url)
                continue

            location_table.update(locations)
            motel_facilities_table.update(motel_facilities)
    finally:
        driver.quit()
    
    return location_table, motel_facilities_table

# %%
def create_dir_if_not_exists(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)


def create_parquet(table, index_name, column_mappings, filename_prefix):
    df = pd.DataFrame.from_dict(table, orient='index')
    df.index.name = index_name
    df.reset_index(inplace=True)
    df.rename(columns=column_mappings, inplace=True)
    
    create_dir_if_not_exists('tables')
    filename = os.path.join('tables', f'{filename_prefix}.parquet')
    
    df.to_parquet(filename, engine='pyarrow', index=False)
    print(f"저장 완료: {filename}")


def save_facilities_table_to_parquet(motel_facilities_table):
    column_mappings = {
        'accomm_main_category': 'accommodations_main_category',
        '트윈베드': 'exist_twinbed',
        '파티룸': 'exist_partyroom',
        '스파/월풀': 'exist_spa/whirlpool',
        '수영장': 'exist_swimming_pool',
        '공주룸': 'exist_princess_room',
        '노천탕': 'exist_open_air_bath',
        '거울룸': 'exist_mirror_room',
        '히노끼탕': 'exist_hinoki_bath',
        '맛사지 베드': 'exist_massage_bed',
        '반신욕': 'exist_half_bath',
        '욕실 TV': 'exist_bathroom_tv',
        '호수뷰': 'exist_lake_view',
        '복층룸': 'exist_duplex_room',
        '바다뷰': 'exist_sea_view',
        '하늘뷰': 'exist_sky_view',
        '야외테라스': 'exist_outdoor_terrace',
        '빔프로젝터': 'exist_beam_projector',
        '사우나/찜질방': 'exist_sauna',
        '3D TV': 'exist_3d_tv',
        '당구대': 'exist_billiard_table',
        '미니바': 'exist_minibar',
        '게임기': 'exist_game_console'
    }
    create_parquet(motel_facilities_table, 'accommodations_id', column_mappings, 'motel_facilities_table')


def save_location_table_to_parquet(location_table):
    column_mappings = {
        'location_major': 'location_major',
        'location_middle': 'location_middle',
        'location_sub': 'location_sub'
    }
    create_parquet(location_table, 'accommodations_id', column_mappings, 'location_table')

# %%
base_url = "https://www.yeogi.com/domestic-accommodations/"

# df = pd.read_csv('tables/accommodations_table.csv', usecols=['accommodations_id', 'accommodations_main_category'])
df = pd.read_parquet('tables/accommodations_table.parquet', columns=['accommodations_id', 'accommodations_main_category'])

accomm_ids = df['accommodations_id'].tolist()
accomm_main_categories = df['accommodations_main_category'].tolist()

location_table, motel_facilities_table = crawl_detail_page(base_url, accomm_ids, accomm_main_categories)
# Out:
# JSON decoding error for accommodation ID 81322: Unterminated string starting at: line 1 column 6447 (char 6446)
# except Script Tag Content: {"@context":"https://schema.org","@type":"WebPage","name":"여주 저스트스테이 호텔-여주대교점, 이천·광주·여주·곤지암, 경기 - 여기어때 특가","description":"Special point\n\n\n\n24년 8월 26 신축 오픈(가오픈)\n\n9월 그랜드 오픈예정\n\n넷플릭스, 웨이브 등 OTT 서비스 이용가능\n\n공용 스타일러 이용가능\n\n연박고객환영(별도문의)\n\n*가오픈 기간 중 내부 주차 시 프런트에 문의 부탁드립니다.*\n","url":"https://www.yeogi.com/domestic-accommodations/81322","mainEntity":{"@type":"Motel","name":"여주 저스트스테이 호텔-여주대교점","alternateName":"여주 저스트스테이 호텔-여주대교점","address":{"@type":"PostalAddress","addressLocality":"경기","addressCountry":"대한민국","streetAddress":"경기 여주시 천송동 515"},"image":["http://image.goodchoice.kr/adimg_new/81322/26756/9b85bbc5a03fd3ed8b679af1c9c38f73.jpg","http://image.goodchoice.kr/adimg_new/81322/627693/0980b9a58bdd5af04434de062098a573.jpg","http://image.goodchoice.kr/adimg_new/81322/627694/75e97792ccc2a3888930e3ffeda360fa.png","http://image.goodchoice.kr/adimg_new/81322/628247/4427c02a3fe8c162185ef7bebd6ae8e3.jpg","http://image.goodchoice.kr/adimg_new/81322/627695/69ae816bc292ace2badc9775f14de0cc.jpg","http://image.goodchoice.kr/adimg_new/81322/627696/e2872fea18c1c0d876e2ad73fdea650c.jpg","http://image.goodchoice.kr/adimg_new/81322/629603/f55665604fbf3b14cb59b59fee872693.jpg","http://image.goodchoice.kr/adimg_new/81322/645966/d07b12191f23a6bbb3e3896421cde84a.jpg","http://image.goodchoice.kr/adimg_new/81322/26756/9b85bbc5a03fd3ed8b679af1c9c38f73.jpg","http://image.goodchoice.kr/adimg_new/81322/26756/3002e8de86e3508e6890a60a0e4ea90e.jpg","http://image.goodchoice.kr/adimg_new/81322/26756/ec57dc454f91ef753da8bdf23ee5fff0.jpg","http://image.goodchoice.kr/adimg_new/81322/26756/c3f0253a6c1ecdc550593924c718f05c.jpg","http://image.goodchoice.kr/adimg_new/81322/26756/4d39a24a45b726407eeb5ddab2f88ea9.jpg","http://image.goodchoice.kr/adimg_new/81322/26756/71c61f85165400be6f1eedabd8b1281e.jpg"],"aggregateRating":{"@type":"AggregateRating","ratingValue":4.8,"ratingCount":39,"reviewCount":39,"bestRating":5,"worstRating":0},"priceRange":null,"description":"Special point\n\n\n\n24년 8월 26 신축 오픈(가오픈)\n\n9월 그랜드 오픈예정\n\n넷플릭스, 웨이브 등 OTT 서비스 이용가능\n\n공용 스타일러 이용가능\n\n연박고객환영(별도문의)\n\n*가오픈 기간 중 내부 주차 시 프런트에 문의 부탁드립니다.*\n","starRating":{"@type":"Rating","ratingValue":"","bestRating":"5"},"hasOfferCatalog":{"@type":"OfferCatalog","name":"객실(룸)","itemListElement":[{"@type":"Offer","itemOffered":{"@type":["Room","LodgingBusiness"],"name":"오픈특가","image":"http://image.goodchoice.kr/adimg_new/81322/627693/0980b9a58bdd5af04434de062098a573.jpg","occupancy":{"@type":"QuantitativeValue","value":"수용 인원 정보"},"checkinTime":"16:00","checkoutTime":"12:00"}},{"@type":"Offer","itemOffered":{"@type":["Room","LodgingBusiness"],"name":"도보특가","image":"http://image.goodchoice.kr/adimg_new/81322/627694/75e97792ccc2a3888930e3ffeda360fa.png","occupancy":{"@type":"QuantitativeValue","value":"수용 인원 정보"},"checkinTime":"17:00","checkoutTime":"12:00"}},{"@type":"Offer","itemOffered":{"@type":["Room","LodgingBusiness"],"name":"슈퍼디럭스( 55\"TV, OTT(넷,티,디, 왓 등), 비데, 샤워부스) ","image":"http://image.goodchoice.kr/adimg_new/81322/628247/4427c02a3fe8c162185ef7bebd6ae8e3.jpg","occupancy":{"@type":"QuantitativeValue","value":"수용 인원 정보"},"checkinTime":"17:00","checkoutTime":"12:00"}},{"@type":"Offer","itemOffered":{"@type":["Room","LodgingBusiness"],"name":"늦은퇴실","image":"http://image.goodchoice.kr/adimg_new/81322/627695/69ae816bc292ace2badc9775f14de0cc.jpg","occupancy":{"@type":"QuantitativeValue","value":"수용 인원 정보"},"checkinTime":"17:00","checkoutTime":"15:00"}},{"@type":"Offer","itemOffered":{"@type":["Room","LodgingBusiness"],"name":"빠른입실","image":"http://image.goodchoice.kr/adimg_new/81322/627696/e2872fea18c1c0d876e2ad73fdea650c.jpg","occupancy":{"@type":"QuantitativeValue","value":"수용 인원 정보"},"checkinTime":"14:00","checkoutTime":"12:00"}},{"@type":"Offer","itemOffered":{"@type":["Room","LodgingBusiness"],"name":"이벤트 안내","image":"http://image.goodchoice.kr/adimg_new/81322/629603/f55665604fbf3b14cb59b59fee872693.jpg","occupancy":{"@type":"QuantitativeValue","value":"수용 인원 정보"},"c ...
# No data for locations exist
# No data for motel_facilities_table exist
# JSON decoding error for accommodation ID 66425: Unterminated string starting at: line 1 column 3683 (char 3682)
# except Script Tag Content: {"@context":"https://schema.org","@type":"WebPage","name":"수원 데이오프호텔-Day off, 수원역·세류·팔달문·구운·장안, 경기 - 여기어때 특가","description":"수원 데이오프호텔-Day off 위치와 시설, 사진과 후기를 확인하고 여기어때 특가로 예약하세요.","url":"https://www.yeogi.com/domestic-accommodations/66425","mainEntity":{"@type":"Motel","name":"수원 데이오프호텔-Day off","alternateName":"수원 데이오프호텔-Day off","address":{"@type":"PostalAddress","addressLocality":"경기","addressCountry":"대한민국","streetAddress":"경기 수원시 장안구 파장동 583-30"},"image":["http://image.goodchoice.kr/adimg_new/66425/337504/c1e32b4ac96dff9e61a86e2b3fbb0d02.jpg","http://image.goodchoice.kr/adimg_new/66425/337505/2b188c1dbfa508f6c6490005bc124d87.jpg","http://image.goodchoice.kr/adimg_new/66425/337506/c2777393102d6a4da9761f804ce32be8.jpg","http://image.goodchoice.kr/adimg_new/66425/343605/e58e245f9dceb490480229eed6b29000.jpg","http://image.goodchoice.kr/adimg_new/66425/337504/c1e32b4ac96dff9e61a86e2b3fbb0d02.jpg","http://image.goodchoice.kr/adimg_new/66425/14703/1f709810577d5c6ef2d047f9bceb2ddc.jpg","http://image.goodchoice.kr/adimg_new/66425/14703/e485b9d4965876a53cac9f55fc659c7c.jpg","http://image.goodchoice.kr/adimg_new/66425/14703/4119e42bc2602f134a0c32847ea11405.jpg","http://image.goodchoice.kr/adimg_new/66425/14703/411938f21c0cf3c43bd3c1cd544824e2.jpg","http://image.goodchoice.kr/adimg_new/66425/14703/3e0830f668d92f5046808a254778ace1.jpg","http://image.goodchoice.kr/adimg_new/66425/14703/91683da384cbd6f923ea06898db0e016.jpg","http://image.goodchoice.kr/adimg_new/66425/14703/56f14d2a1ec908654033347bebaea809.jpg","http://image.goodchoice.kr/adimg_new/66425/14703/476cdfa956a831750b58136f218aae33.jpg","http://image.goodchoice.kr/adimg_new/66425/14703/c73c46afc78795e45dbce5c00b358c88.jpg"],"aggregateRating":{"@type":"AggregateRating","ratingValue":4.6,"ratingCount":451,"reviewCount":451,"bestRating":5,"worstRating":0},"priceRange":"33000원 - 48000원","starRating":{"@type":"Rating","ratingValue":"","bestRating":"5"},"hasOfferCatalog":{"@type":"OfferCatalog","name":"객실(룸)","itemListElement":[{"@type":"Offer","itemOffered":{"@type":["Room","LodgingBusiness"],"name":"미니","image":"http://image.goodchoice.kr/adimg_new/66425/337505/2b188c1dbfa508f6c6490005bc124d87.jpg","occupancy":{"@type":"QuantitativeValue","value":"수용 인원 정보"},"checkinTime":"18:00","checkoutTime":"10:00"}},{"@type":"Offer","itemOffered":{"@type":["Room","LodgingBusiness"],"name":"스탠다드","image":"http://image.goodchoice.kr/adimg_new/66425/337506/c2777393102d6a4da9761f804ce32be8.jpg","occupancy":{"@type":"QuantitativeValue","value":"수용 인원 정보"},"checkinTime":"18:00","checkoutTime":"10:00"}},{"@type":"Offer","itemOffered":{"@type":["Room","LodgingBusiness"],"name":"트윈","image":"http://image.goodchoice.kr/adimg_new/66425/343605/e58e245f9dceb490480229eed6b29000.jpg","occupancy":{"@type":"QuantitativeValue","value":"수용 인원 정보"},"checkinTime":"18:00","checkoutTime":"10:00"}},{"@type":"Offer","itemOffered":{"@type":["Room","LodgingBusiness"],"name":"VIP","image":"http://image.goodchoice.kr/adimg_new/66425/337504/c1e32b4ac96dff9e61a86e2b3fbb0d02.jpg","occupancy":{"@type":"QuantitativeValue","value":"수용 인원 정보"},"checkinTime":"18:00","checkoutTime":"10:00"}}]},"review":[{"@type":"Review","author":{"@type":"Person","name":"칠레악어"},"reviewRating":{"@type":"Rating","ratingValue":4.85},"datePublished":"2024-10-13","image":["https://image.withstatic.com/22/408/142/c6e7011fe3074930b04d12f81bb296d2.jpg","https://image.withstatic.com/337/116/198/85794a65a37748f0adfaf3be8c5ba4a8.jpg","https://image.withstatic.com/17/393/363/675df69af2d2445184338b0f05ccca23.jpg","https://image.withstatic.com/68/0/73/c0994ecd35584f0db917bb120a6114bd.jpg"],"itemReviewed":{"@type":"Room","name":"미니"},"reviewBody":"쥬아요!!! 요즘 침구류랑 방 진짜 청결해 염&gt;-
# No data for locations exist
# No data for motel_facilities_table exist
# JSON decoding error for accommodation ID 56409: Unterminated string starting at: line 1 column 5092 (char 5091)
# except Script Tag Content: {"@context":"https://schema.org","@type":"WebPage","name":"수원시청역 호텔 딘, 수원시청·권선·영통, 경기 - 여기어때 특가","description":"수원시청역 호텔 딘 위치와 시설, 사진과 후기를 확인하고 여기어때 특가로 예약하세요.","url":"https://www.yeogi.com/domestic-accommodations/56409","mainEntity":{"@type":"Motel","name":"수원시청역 호텔 딘","alternateName":"수원시청역 호텔 딘","address":{"@type":"PostalAddress","addressLocality":"경기","addressCountry":"대한민국","streetAddress":"경기 수원시 권선구 권선동 1017-6"},"image":["https://image.goodchoice.kr/adimg_new/56409/240358/1b1056fbf69c8d9d2bc054afc5d0b44f.jpg","https://image.goodchoice.kr/adimg_new/56409/240362/29b9a2a2a0428ba82417cf49b4c2a97d.jpg","https://image.goodchoice.kr/adimg_new/56409/240361/5d32e9de9fecb318e1dad54d1ee6ec5c.jpg","https://image.goodchoice.kr/adimg_new/56409/240360/1f87b26f5ec780b06f1394b7d49ddf9e.jpg","https://image.goodchoice.kr/adimg_new/56409/240359/203b0f749c29b06b234dc8643278f4da.jpg","https://image.goodchoice.kr/adimg_new/56409/240358/1b1056fbf69c8d9d2bc054afc5d0b44f.jpg","https://image.goodchoice.kr/adimg_new/56409/10115/8cde392788bcf0bb254b6646c9129b7f.jpg","https://image.goodchoice.kr/adimg_new/56409/10115/d241f74beb9b92c401bdf3025cc395f0.jpg","https://image.goodchoice.kr/adimg_new/56409/10115/dc2dbec0a42aedb423d85e52ac469b54.jpg","https://image.goodchoice.kr/adimg_new/56409/10115/430afed248561dbb6616d106fa663af2.jpg","https://image.goodchoice.kr/adimg_new/56409/10115/1dbc5ce7ddd0b3d1f3c9b88696b75e38.jpg","https://image.goodchoice.kr/adimg_new/56409/10115/31a593436fc67c5ebdc65b9f5993c757.jpg","https://image.goodchoice.kr/adimg_new/56409/10115/452ae33c10501314c748c0111c25f974.jpg","https://image.goodchoice.kr/adimg_new/56409/10115/02b52f2750c73972e055917d414720e6.jpg","https://image.goodchoice.kr/adimg_new/56409/10115/fd19c24f6af0fa44ae028ae648e2957e.jpg","https://image.goodchoice.kr/adimg_new/56409/10115/6b038137b21003ff700d69169475416b.jpg","https://image.goodchoice.kr/adimg_new/56409/10115/6779a2eb0391eaddecca009b7d5c9fc2.jpg","https://image.goodchoice.kr/adimg_new/56409/10115/bf94aaaf70d4363102234faf04516245.jpg","https://image.goodchoice.kr/adimg_new/56409/10115/0c4887327bb688ede34dd04d60755a66.jpg","https://image.goodchoice.kr/adimg_new/56409/10115/8ccecb4a647f10dd897443fda6d44280.jpg"],"aggregateRating":{"@type":"AggregateRating","ratingValue":4.55,"ratingCount":323,"reviewCount":323,"bestRating":5,"worstRating":0},"priceRange":"35000원 - 50000원","starRating":{"@type":"Rating","ratingValue":"","bestRating":"5"},"hasOfferCatalog":{"@type":"OfferCatalog","name":"객실(룸)","itemListElement":[{"@type":"Offer","itemOffered":{"@type":["Room","LodgingBusiness"],"name":"당일특가","image":"https://image.goodchoice.kr/adimg_new/56409/240362/29b9a2a2a0428ba82417cf49b4c2a97d.jpg","occupancy":{"@type":"QuantitativeValue","value":"수용 인원 정보"},"checkinTime":"18:00","checkoutTime":"13:00"}},{"@type":"Offer","itemOffered":{"@type":["Room","LodgingBusiness"],"name":"스탠다드","image":"https://image.goodchoice.kr/adimg_new/56409/240361/5d32e9de9fecb318e1dad54d1ee6ec5c.jpg","occupancy":{"@type":"QuantitativeValue","value":"수용 인원 정보"},"checkinTime":"18:00","checkoutTime":"13:00"}},{"@type":"Offer","itemOffered":{"@type":["Room","LodgingBusiness"],"name":"스탠다드(2PC)","image":"https://image.goodchoice.kr/adimg_new/56409/240360/1f87b26f5ec780b06f1394b7d49ddf9e.jpg","occupancy":{"@type":"QuantitativeValue","value":"수용 인원 정보"},"checkinTime":"18:00","checkoutTime":"13:00"}},{"@type":"Offer","itemOffered":{"@type":["Room","LodgingBusiness"],"name":"디럭스(2PC,스파)","image":"https://image.goodchoice.kr/adimg_new/56409/240359/203b0f749c29b06b234dc8643278f4da.jpg","occupancy":{"@type":"QuantitativeValue","value":"수용 인원 정보"},"checkinTime":"18:00","checkoutTime":"13:00"}},{"@type":"Offer","itemOffered":{"@type":["Room","LodgingBusiness"],"name":"디럭스(1PC,스파)","image":"https://image.goodchoice.kr/adimg_new/56409/240358/1b1056fbf69c8d9d2bc054afc5d0b44f.jpg","occupancy":{"@type":"QuantitativeValue","value":"수용 인원 정보"},"checkinTime":"18:00","checkoutTime":"13:0 ...
# No data for locations exist
# No data for motel_facilities_table exist

# %%
save_facilities_table_to_parquet(motel_facilities_table)
save_location_table_to_parquet(location_table)
# Out:
# 저장 완료: tables/motel_facilities_table.parquet
# 저장 완료: tables/location_table.parquet
